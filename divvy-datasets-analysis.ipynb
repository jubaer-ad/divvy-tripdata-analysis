# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Install required packages
# tidyverse for data import and wrangling\
# lubridate for date functions\
# ggplot for visualization

# %%
library(tidyverse)  #helps wrangle data
library(lubridate)  #helps wrangle date attributes
library(ggplot2)  #helps visualize data
getwd() #displays your working directory
setwd("../input/divvytripdataraw/")
# Out:
# [1] "/kaggle/input/divvytripdataraw"

# %% [markdown]
# # STEP 1: COLLECT DATA
# ## Upload Divvy datasets (csv files) here

# %%
d202106 <- read_csv("202106-divvy-tripdata.csv")
d202107 <- read_csv("202107-divvy-tripdata.csv")
d202108 <- read_csv("202108-divvy-tripdata.csv")
d202109 <- read_csv("202109-divvy-tripdata.csv")
d202110 <- read_csv("202110-divvy-tripdata.csv")
d202111 <- read_csv("202111-divvy-tripdata.csv")
d202112 <- read_csv("202112-divvy-tripdata.csv")
d202201 <- read_csv("202201-divvy-tripdata.csv")
d202202 <- read_csv("202202-divvy-tripdata.csv")
d202203 <- read_csv("202203-divvy-tripdata.csv")
d202204 <- read_csv("202204-divvy-tripdata.csv")
d202205 <- read_csv("202205-divvy-tripdata.csv")
# Out:
# New names:
# • `` -> `...14`
# Rows: 608778 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): ride_id, rideable_type, started_at, ended_at, start_station_name, s...
# dbl (4): start_lat, start_lng, end_lat, end_lng
# lgl (1): ...14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `` -> `...14`
# Rows: 692321 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): ride_id, rideable_type, started_at, ended_at, start_station_name, s...
# dbl (4): start_lat, start_lng, end_lat, end_lng
# lgl (1): ...14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `` -> `...14`
# Rows: 674409 Columns: 14
# ...

# %% [markdown]
# # STEP 2: WRANGLE DATA AND COMBINE INTO A SINGLE FILE
# ## Compare column names each of the files
# ## While the names don't have to be in the same order, they DO need to match perfectly before we can use a command to join them into one file

# %%
colnames(d202106)
colnames(d202107)
colnames(d202108)
colnames(d202109)
colnames(d202110)
colnames(d202111)
colnames(d202112)
colnames(d202201)
colnames(d202202)
colnames(d202203)
colnames(d202204)
colnames(d202205)
# Out:
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "start_station_name" "start_station_id"
#  [7] "end_station_name"   "end_station_id"     "start_lat"
# [10] "start_lng"          "end_lat"            "end_lng"
# [13] "member_casual"      "...14"
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "start_station_name" "start_station_id"
#  [7] "end_station_name"   "end_station_id"     "start_lat"
# [10] "start_lng"          "end_lat"            "end_lng"
# [13] "member_casual"      "...14"
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "start_station_name" "start_station_id"
#  [7] "end_station_name"   "end_station_id"     "start_lat"
# [10] "start_lng"          "end_lat"            "end_lng"
# [13] "member_casual"      "...14"
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "start_station_name" "start_station_id"
# ...

# %% [markdown]
# ## Renaming columns

# %%
d202106 <- rename(d202106,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)
d202107 <- rename(d202107,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)
d202108 <- rename(d202108,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)
d202109 <- rename(d202109,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)
d202110 <- rename(d202110,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)
d202111 <- rename(d202111,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)
d202112 <- rename(d202112,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)
d202201 <- rename(d202201,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)
d202202 <- rename(d202202,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)
d202203 <- rename(d202203,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)
d202204 <- rename(d202204,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)
d202205 <- rename(d202205,
                  trip_id = ride_id,
                  bike_id = rideable_type,
                  start_time = started_at,
                  end_time = ended_at,
                  from_station_name = start_station_name,
                  from_station_id = start_station_id,
                  to_station_name = end_station_name,
                  to_station_id = end_station_id,
                  user_type = member_casual)

# %% [markdown]
# ## Inspect the dataframes and look for incongruencies (condition of not being in agreement)

# %%
colnames(d202106)
colnames(d202107)
colnames(d202108)
colnames(d202109)
colnames(d202110)
colnames(d202111)
colnames(d202112)
colnames(d202201)
colnames(d202202)
colnames(d202203)
colnames(d202204)
colnames(d202205)
str(d202106)
str(d202107)
str(d202108)
str(d202109)
str(d202110)
str(d202111)
str(d202112)
str(d202201)
str(d202202)
str(d202203)
str(d202204)
str(d202205)
# Out:
#  [1] "trip_id"           "bike_id"           "start_time"
#  [4] "end_time"          "from_station_name" "from_station_id"
#  [7] "to_station_name"   "to_station_id"     "start_lat"
# [10] "start_lng"         "end_lat"           "end_lng"
# [13] "user_type"         "...14"
#  [1] "trip_id"           "bike_id"           "start_time"
#  [4] "end_time"          "from_station_name" "from_station_id"
#  [7] "to_station_name"   "to_station_id"     "start_lat"
# [10] "start_lng"         "end_lat"           "end_lng"
# [13] "user_type"         "...14"
#  [1] "trip_id"           "bike_id"           "start_time"
#  [4] "end_time"          "from_station_name" "from_station_id"
#  [7] "to_station_name"   "to_station_id"     "start_lat"
# [10] "start_lng"         "end_lat"           "end_lng"
# [13] "user_type"         "...14"
#  [1] "trip_id"           "bike_id"           "start_time"
#  [4] "end_time"          "from_station_name" "from_station_id"
# ...

# %% [markdown]
# ## Stack individual month's data frames into one big data frame

# %%
all_trips <- bind_rows(d202106, d202107, d202108, d202109,
                       d202110, d202111, d202112, d202201, d202202, d202203, d202204, d202205)

# %% [markdown]
# ## Checking dimension

# %%
dim(all_trips)
# Out:
# [1] 4667299      14

# %% [markdown]
# ## Removing non-interesting columns

# %%
all_trips <- all_trips %>% 
  select(-c(start_lat, start_lng, end_lat, end_lng))
# Out:
# Error in `select()`:
# ! Can't subset columns that don't exist.
# ✖ Column `start_lat` doesn't exist.
# Traceback:
#
# 1. all_trips %>% select(-c(start_lat, start_lng, end_lat, end_lng))
# 2. select(., -c(start_lat, start_lng, end_lat, end_lng))
# 3. select.data.frame(., -c(start_lat, start_lng, end_lat, end_lng))
# 4. tidyselect_fix_call(tidyselect::eval_select(expr(c(...)), .data),
#  .     call = error_call)
# 5. withCallingHandlers(expr, error = function(cnd) {
#  .     cnd$call <- call
#  .     cnd$parent <- NULL
#  .     cnd_signal(cnd)
#  . })
# 6. tidyselect::eval_select(expr(c(...)), .data)
# 7. eval_select_impl(data, names(data), as_quosure(expr, env), include = include,
#  .     exclude = exclude, strict = strict, name_spec = name_spec,
#  .     allow_rename = allow_rename, error_call = error_call, )
# 8. with_subscript_errors(vars_select_eval(vars, expr, strict = strict,
#  .     data = x, name_spec = name_spec, uniquely_named = uniquely_named,
# ...

# %% [markdown]
# ## Converting columns to another data type

# %%
all_trips <- all_trips %>%
  mutate(start_time = mdy_hm(start_time), end_time = mdy_hm(end_time))

# %% [markdown]
# # STEP 3: CLEAN UP AND ADD DATA TO PREPARE FOR ANALYSIS
#
# ## Inspect the new table that has been created

# %%
colnames(all_trips)
nrow(all_trips)
dim(all_trips)
head(all_trips)
str(all_trips)
summary(all_trips)
# Out:
#  [1] "trip_id"           "bike_id"           "start_time"
#  [4] "end_time"          "from_station_name" "from_station_id"
#  [7] "to_station_name"   "to_station_id"     "user_type"
# [10] "...14"
# [1] 4667299
# [1] 4667299      10
#   trip_id          bike_id      start_time          end_time
# 1 0D904FEC5F84A538 classic_bike 2021-06-04 07:29:00 2021-06-04 07:45:00
# 2 C4185F300D6B552B classic_bike 2021-06-23 08:39:00 2021-06-23 08:41:00
# 3 60F97090AC85F55E classic_bike 2021-06-27 12:26:00 2021-06-27 12:34:00
# 4 FBC7B1F0160AA304 classic_bike 2021-06-01 12:30:00 2021-06-01 12:33:00
# 5 37A52001AEEFA4E5 classic_bike 2021-06-01 11:32:00 2021-06-01 11:34:00
# 6 E49E5426F0B74023 classic_bike 2021-06-17 17:55:00 2021-06-17 17:58:00
#   from_station_name         from_station_id to_station_name
# 1 Orleans St & Elm St       TA1306000006    Orleans St & Elm St
# 2 Desplaines St & Kinzie St TA1306000003    Kingsbury St & Kinzie St
# ...

# %% [markdown]
# ## Begin by seeing how many observations fall under each user_type

# %%
table(all_trips$user_type)
# Out:
#  casual  member
# 2019233 2648066

# %% [markdown]
# ## Add columns that list the date, month, day, year and day of week of each ride

# %%
all_trips$date <- as.Date(all_trips$start_time)
all_trips$month <- format(as.Date(all_trips$date), "%m")
all_trips$day <- format(as.Date(all_trips$date), "%d")
all_trips$year <- format(as.Date(all_trips$date), "%Y")
all_trips$day_of_week <- format(as.Date(all_trips$date), "%A")

# %% [markdown]
# ## Add a "ride_length" calculation to all_trips (in seconds)

# %%
all_trips$ride_length <- difftime(all_trips$end_time,all_trips$start_time)

# %% [markdown]
# ## Inspect the structure of the columns

# %%
head(all_trips)
colnames(all_trips)
# Out:
# [1] "double"

# %% [markdown]
# ## Convert "ride_length" from Double to numeric

# %%
all_trips$ride_length <- as.numeric(as.character(all_trips$ride_length))
is.numeric(all_trips$ride_length)
# Out:
# [1] TRUE

# %% [markdown]
# ## Creating copy of dataset with all positive ride_length values

# %%
all_trips_v2 <-all_trips[!(all_trips$ride_length < 0), ]

# %% [markdown]
# # STEP 4: CONDUCT DESCRIPTIVE ANALYSIS
#
# ## Descriptive analysis on ride_length (all figures in seconds)

# %%
mean(all_trips_v2$ride_length) # straight average (total ride length / rides)
median(all_trips_v2$ride_length)  # midpoint number in the ascending array of ride lengths
max(all_trips_v2$ride_length) # longest ride
min(all_trips_v2$ride_length) # shortest ride
# Out:
# [1] 1212.907
# [1] 720
# [1] 3356640
# [1] 0

# %% [markdown]
# ## Doing all four operations above using summary()

# %%
summary(all_trips_v2$ride_length)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0     420     720    1213    1260 3356640

# %% [markdown]
# ## Compare members and casual users

# %%
aggregate(all_trips_v2$ride_length ~ all_trips_v2$user_type, FUN = mean)
aggregate(all_trips_v2$ride_length ~ all_trips_v2$user_type, FUN = median)
aggregate(all_trips_v2$ride_length ~ all_trips_v2$user_type, FUN = max)
aggregate(all_trips_v2$ride_length ~ all_trips_v2$user_type, FUN = min)
# Out:
#   all_trips_v2$user_type all_trips_v2$ride_length
# 1 casual                 1806.104
# 2 member                  760.575
#   all_trips_v2$user_type all_trips_v2$ride_length
# 1 casual                 960
# 2 member                 540
#   all_trips_v2$user_type all_trips_v2$ride_length
# 1 casual                 3356640
# 2 member                   89700
#   all_trips_v2$user_type all_trips_v2$ride_length
# 1 casual                 0
# 2 member                 0

# %%
View(all_trips_v2[all_trips_v2$ride_length > 3000000,])
# Out:
#   trip_id          bike_id     start_time          end_time
# 1 E6E1E5BFFD72ECEC docked_bike 2021-06-05 23:33:00 2021-07-12 13:55:00
# 2 7F0578ABF030FC83 docked_bike 2021-06-04 22:03:00 2021-07-13 14:15:00
# 3 F043F0F6A1AA4F85 docked_bike 2021-06-05 02:27:00 2021-07-13 22:51:00
#   from_station_name       from_station_id to_station_name
# 1 Clark St & Lake St      KA1503000012    Base - 2132 W Hubbard Warehouse
# 2 Streeter Dr & Grand Ave 13022           Base - 2132 W Hubbard Warehouse
# 3 Michigan Ave & Lake St  TA1305000011    Malcolm X College Vaccination Site
#   to_station_id                       user_type ...14 date       month day year
# 1 Hubbard Bike-checking (LBS-WH-TEST) casual    NA    2021-06-05 06    05  2021
# 2 Hubbard Bike-checking (LBS-WH-TEST) casual    NA    2021-06-04 06    04  2021
# 3 631                                 casual    NA    2021-06-05 06    05  2021
#   day_of_week ride_length
# 1 Saturday    3162120
# 2 Friday      3341520
# 3 Saturday    3356640

# %% [markdown]
# ## See the average ride time by each day for members vs casual users

# %%
aggregate(all_trips_v2$ride_length ~ all_trips_v2$user_type + all_trips_v2$day_of_week, FUN = mean)
# Out:
#    all_trips_v2$user_type all_trips_v2$day_of_week all_trips_v2$ride_length
# 1  casual                 Friday                   1702.7615
# 2  member                 Friday                    741.9218
# 3  casual                 Monday                   1806.2629
# 4  member                 Monday                    736.6135
# 5  casual                 Saturday                 1968.0092
# 6  member                 Saturday                  856.6115
# 7  casual                 Sunday                   2053.6663
# 8  member                 Sunday                    867.1107
# 9  casual                 Thursday                 1628.6732
# 10 member                 Thursday                  724.4060
# 11 casual                 Tuesday                  1569.9950
# 12 member                 Tuesday                   711.8370
# 13 casual                 Wednesday                1597.3296
# 14 member                 Wednesday                 721.8179

# %% [markdown]
# ## Fixing out of ordered day of week

# %%
all_trips_v2$day_of_week <- ordered(all_trips_v2$day_of_week, levels = c("Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"))
aggregate(all_trips_v2$ride_length ~ all_trips_v2$user_type + all_trips_v2$day_of_week, FUN = mean)
# Out:
#    all_trips_v2$user_type all_trips_v2$day_of_week all_trips_v2$ride_length
# 1  casual                 Sunday                   2053.6663
# 2  member                 Sunday                    867.1107
# 3  casual                 Monday                   1806.2629
# 4  member                 Monday                    736.6135
# 5  casual                 Tuesday                  1569.9950
# 6  member                 Tuesday                   711.8370
# 7  casual                 Wednesday                1597.3296
# 8  member                 Wednesday                 721.8179
# 9  casual                 Thursday                 1628.6732
# 10 member                 Thursday                  724.4060
# 11 casual                 Friday                   1702.7615
# 12 member                 Friday                    741.9218
# 13 casual                 Saturday                 1968.0092
# 14 member                 Saturday                  856.6115

# %% [markdown]
# ## Analyzing ridership data by type and weekday

# %%
all_trips_v2 %>%
  mutate(weekday = wday(start_time, label = TRUE)) %>% 
  group_by(user_type, weekday) %>% 
  summarise(number_of_rides = n(),
            average_duration = mean(ride_length)) %>% 
  arrange(user_type, weekday)
# Out:
# `summarise()` has grouped output by 'user_type'. You can override using the
# `.groups` argument.
#    user_type weekday number_of_rides average_duration
# 1  casual    Sun     384627          2053.6663
# 2  casual    Mon     234505          1806.2629
# 3  casual    Tue     218155          1569.9950
# 4  casual    Wed     217439          1597.3296
# 5  casual    Thu     236564          1628.6732
# 6  casual    Fri     279857          1702.7615
# 7  casual    Sat     448059          1968.0092
# 8  member    Sun     314114           867.1107
# 9  member    Mon     375450           736.6135
# 10 member    Tue     424917           711.8370
# 11 member    Wed     415280           721.8179
# 12 member    Thu     403070           724.4060
# 13 member    Fri     364202           741.9218
# 14 member    Sat     350999           856.6115

# %% [markdown]
# ## Setting working directory back to default to plot

# %%
setwd('/kaggle/working')

# %% [markdown]
# ## Let's visualize the number of rides by rider type

# %%
all_trips_v2 %>%
  mutate(weekday = wday(start_time, label = TRUE)) %>% 
  group_by(user_type, weekday) %>% 
  summarise(number_of_rides = n(),
            average_duration = mean(ride_length)) %>% 
  arrange(user_type, weekday) %>% 
  ggplot(aes(x = weekday, y = number_of_rides, fill = user_type)) +
  geom_col(position = "dodge")
# Out:
# `summarise()` has grouped output by 'user_type'. You can override using the
# `.groups` argument.

# %% [markdown]
# ## Let's create a visualization for average duration

# %%
all_trips_v2 %>% 
  mutate(weekday = wday(start_time, label = TRUE)) %>% 
  group_by(user_type, weekday) %>% 
  summarise(number_of_rides = n(),
            average_duration = mean(ride_length)) %>% 
  arrange(user_type, weekday) %>% 
  ggplot(aes(x = weekday, y = average_duration, fill = user_type)) +
  geom_col(position = "dodge")
# Out:
# `summarise()` has grouped output by 'user_type'. You can override using the
# `.groups` argument.

# %% [markdown]
# ## Creating a csv file with results that can be used later to visualize in Excel, Tableau, or presentation software

# %%
counts <- aggregate(all_trips_v2$ride_length ~ all_trips_v2$user_type + all_trips_v2$day_of_week, FUN = mean)
write.csv(counts, file = 'avg_ride_length.csv')

# %% [markdown]
# # Optional (Saving all cleaned data together)

# %%
# write.csv(all_trips_v2, file = 'all_trips_v2.csv')
